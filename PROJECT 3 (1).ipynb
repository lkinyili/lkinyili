# %%
1. You are provided with the  dataset (insurance.csv).

2. Proceed and undertake the following actions :
    a. Rename the column name from 'Sex' to 'Gender'.

    b. Create a new dataframe('age_expenses') to consist only of columns 'age','gender' and         'expenses'.

3.Display an output of  those insured, who are older than 35 years.

4.How many people over 35 years have an insurance cover ?

5. What are some of the conclusions you can derive from this dataset ?

# %%
#Statement of the problem

# %%
#import relevant libraries
import pandas as pd

# %%
insurance=pd.read_csv(r'C:\Users\pc\Downloads\insurance (1).csv')
insurance
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df=insurance.copy()

# %%
# 2. Proceed and undertake the following actions :
   # a. Rename the column name from 'Sex' to 'Gender'.

# %%
df1 = df.rename(columns={'sex': 'gender'})
df1
# Out:
#       age  gender   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# b. Create a new dataframe('age_expenses') to consist only of columns 'age','gender' and 'expenses'.

# %%
age_expenses=(df1[['age','gender','expenses']])
age_expenses
# Out:
#       age  gender  expenses
# 0      19  female  16884.92
# 1      18    male   1725.55
# 2      28    male   4449.46
# 3      33    male  21984.47
# 4      32    male   3866.86
# ...   ...     ...       ...
# 1333   50    male  10600.55
# 1334   18  female   2205.98
# 1335   18  female   1629.83
# 1336   21  female   2007.95
# 1337   61  female  29141.36
#
# [1338 rows x 3 columns]

# %%
# 3.Display an output of  those insured, who are older than 35 years.

# %%
insured=  df[df1[ 'age' ] > 35]
insured
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 6      46  female  33.4         1     no  southeast   8240.59
# 7      37  female  27.7         3     no  northwest   7281.51
# 8      37    male  29.8         2     no  northeast   6406.41
# 9      60  female  25.8         0     no  northwest  28923.14
# 11     62  female  26.3         0    yes  southeast  27808.73
# ...   ...     ...   ...       ...    ...        ...       ...
# 1329   52    male  38.6         2     no  southwest  10325.21
# 1330   57  female  25.7         2     no  southeast  12629.17
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [764 rows x 7 columns]

# %%
# 4.How many people over 35 years have an insurance cover ?

# %%
(insured['age']> 35).count()
# Out:
# 764

# %%
# 5. What are some of the conclusions you can derive from this dataset ?

# %%
df1.head()
# Out:
#    age  gender   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df1.head()
# Out:
#    age  gender   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df1.shape
# Out:
# (1338, 7)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of       age  gender   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]>

# %%
df1.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df2 = df1.to_string()
print(df2)
# Out:
#       age  gender   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# 5      31  female  25.7         0     no  southeast   3756.62
# 6      46  female  33.4         1     no  southeast   8240.59
# 7      37  female  27.7         3     no  northwest   7281.51
# 8      37    male  29.8         2     no  northeast   6406.41
# 9      60  female  25.8         0     no  northwest  28923.14
# 10     25    male  26.2         0     no  northeast   2721.32
# 11     62  female  26.3         0    yes  southeast  27808.73
# 12     23    male  34.4         0     no  southwest   1826.84
# 13     56  female  39.8         0     no  southeast  11090.72
# ...

# %%
df1.to_csv('insurance1.csv',index=False)

# %%
df1.to_csv(r'C:\Users\pc\Downloads\insurance1.csv',index=False)
