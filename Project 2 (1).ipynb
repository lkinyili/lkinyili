# %% [markdown]
# Assignment 7

# %% [markdown]
# Using the recent-grads.csv dataset, answer all the questions .

# %% [markdown]
# 1 a.Display the data for those who have taken Psychology & Social Work as their major category .

# %% [markdown]
#   b. Show the share of women graduates above 0.5 who have taken Psychology & Social Work as their major category.

# %% [markdown]
# 2.Create a Data Frame showing the number of graduates of  Chemical Engineering with Full time year round employment.

# %% [markdown]
# 3.Output a subset consisting of graduates of Psychology & Social Work  and show their respective employment status,i.e. :
#    those employed,part-time employment,full time employment & those without jobs.

# %% [markdown]
# 4. Use loc & iloc methods to display the  rows 21-25 and the last three columns of this dataset.

# %%
#Statement of the problem
#1 a.Display the data for those who have taken Psychology & Social Work as their major category .

# %%
#import relevant libraries
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\pc\Downloads\recent-grads.csv')

# %%
df
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
df['Major_category'] == 'Psychology & Social Work'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 168    False
# 169     True
# 170     True
# 171     True
# 172    False
# Name: Major_category, Length: 173, dtype: bool

# %%
#slice the relevant column
Social_Work_Major_category = df[df['Major_category'] == 'Psychology & Social Work']	
Social_Work_Major_category
# Out:
#      Rank  Major_code                                      Major     Total  \
# 70     71        5205   INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY    3014.0
# 91     92        5206                          SOCIAL PSYCHOLOGY    1386.0
# 145   146        5200                                 PSYCHOLOGY  393735.0
# 151   152        5404                                SOCIAL WORK   53552.0
# 155   156        5299                   MISCELLANEOUS PSYCHOLOGY    9628.0
# 156   157        5403  HUMAN SERVICES AND COMMUNITY ORGANIZATION    9374.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY    2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY    2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY    4626.0
#
#          Men     Women            Major_category  ShareWomen  Sample_size  \
# 70    1075.0    1939.0  Psychology & Social Work    0.643331           24
# ...

# %%
#b. Show the share of women graduates above 0.5 who have taken Psychology & Social Work as their major category.

# %%
(df['Major_category'] == 'Psychology & Social Work') & (df['ShareWomen'] >= 0.5)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 168    False
# 169     True
# 170     True
# 171     True
# 172    False
# Length: 173, dtype: bool

# %%
filter_criteria = (df['Major_category'] == 'Psychology & Social Work') & (df['ShareWomen'] >= 0.5)

# %%
df[filter_criteria]
# Out:
#      Rank  Major_code                                      Major     Total  \
# 70     71        5205   INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY    3014.0
# 91     92        5206                          SOCIAL PSYCHOLOGY    1386.0
# 145   146        5200                                 PSYCHOLOGY  393735.0
# 151   152        5404                                SOCIAL WORK   53552.0
# 155   156        5299                   MISCELLANEOUS PSYCHOLOGY    9628.0
# 156   157        5403  HUMAN SERVICES AND COMMUNITY ORGANIZATION    9374.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY    2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY    2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY    4626.0
#
#          Men     Women            Major_category  ShareWomen  Sample_size  \
# 70    1075.0    1939.0  Psychology & Social Work    0.643331           24
# ...

# %%
len(df[filter_criteria])
# Out:
# 9

# %%
#2. Create a Data Frame showing the number of graduates of Chemical Engineering with Full time year round employment

# %%
df1=pd.read_csv(r'C:\Users\pc\Downloads\recent-grads.csv')
df1
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
filter_criteria = (df['Major'] == 'CHEMICAL ENGINEERING') & (df['Full_time_year_round'])

# %%
cols = ['Major','Full_time_year_round']
df1 = df.loc[filter_criteria,cols]
df1
# Out:
#                   Major  Full_time_year_round
# 4  CHEMICAL ENGINEERING                 16697

# %%
#3.Output a subset consisting of graduates of Psychology & Social Work and show their respective employment status,i.e. : those employed,part-time employment,full time employment & those without jobs.

# %%
filter_criteria = (df['Major_category'] == 'Psychology & Social Work')
df[filter_criteria]
# Out:
#      Rank  Major_code                                      Major     Total  \
# 70     71        5205   INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY    3014.0
# 91     92        5206                          SOCIAL PSYCHOLOGY    1386.0
# 145   146        5200                                 PSYCHOLOGY  393735.0
# 151   152        5404                                SOCIAL WORK   53552.0
# 155   156        5299                   MISCELLANEOUS PSYCHOLOGY    9628.0
# 156   157        5403  HUMAN SERVICES AND COMMUNITY ORGANIZATION    9374.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY    2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY    2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY    4626.0
#
#          Men     Women            Major_category  ShareWomen  Sample_size  \
# 70    1075.0    1939.0  Psychology & Social Work    0.643331           24
# ...

# %%
cols = ['Employed','Part_time','Full_time_year_round','Unemployed']

# %%
df2 = df.loc[filter_criteria,cols]
df2
# Out:
#      Employed  Part_time  Full_time_year_round  Unemployed
# 70       2343       1095                  1409         286
# 91       1080        433                   529          33
# 145    307933     115172                174438       28169
# 151     45038      13481                 27588        3329
# 155      7653       3221                  3838         419
# 156      8294       2405                  5061         326
# 169      2125        572                  1211         148
# 170      2101        648                  1293         368
# 171      3777        965                  2738         214

# %%
#4. Use loc & iloc methods to display the rows 21-25 and the last three columns of this dataset.

# %%
df.loc[20:24]
# Out:
#     Rank  Major_code                                          Major     Total  \
# 20    21        2102                               COMPUTER SCIENCE  128319.0
# 21    22        1104                                   FOOD SCIENCE       NaN
# 22    23        2502              ELECTRICAL ENGINEERING TECHNOLOGY   11565.0
# 23    24        2413    MATERIALS ENGINEERING AND MATERIALS SCIENCE    2993.0
# 24    25        6212  MANAGEMENT INFORMATION SYSTEMS AND STATISTICS   18713.0
#
#         Men    Women                   Major_category  ShareWomen  \
# 20  99743.0  28576.0          Computers & Mathematics    0.222695
# 21      NaN      NaN  Agriculture & Natural Resources         NaN
# 22   8181.0   3384.0                      Engineering    0.292607
# 23   2020.0    973.0                      Engineering    0.325092
# 24  13496.0   5217.0                         Business    0.278790
#
#     Sample_size  Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
df.iloc[21:26,18:21]
# Out:
#     College_jobs  Non_college_jobs  Low_wage_jobs
# 21          1183              1274            485
# 22          5126              2686            696
# 23          1911               305             70
# 24          6342              5741            708
# 25         28526              9356           2899
