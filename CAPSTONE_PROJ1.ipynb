# %% [markdown]
#              Python For Data Science: Capstone Project 2-2025

# %% [markdown]
#      Section 1 : (50 Marks)
#     Phase 1 - Data Collection

# %%
#Statement of the problem

# %% [markdown]
# Here is a data of every public school in middle Tennessee. The data also includes various demographic, school faculty, and income variables. You    need to convert the data into useful information.
#     • Read the data in pandas data frame
#     • Describe the data to find more details

# %%
#import relevant libraries                  
import pandas as pd                
import matplotlib.pyplot as plt     
import seaborn as sns

# %%
middle_tn_schools=pd.read_excel(r'C:\Users\pc\Downloads\middle_tn_schools.xlsx')

# %%
middle_tn_schools
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 0     Allendale Elementary School              5   851             10
# 1             Anderson Elementary              2   412             71
# 2                Avoca Elementary              4   482             43
# 3                   Bailey Middle              0   394             91
# 4             Barfield Elementary              4   948             26
# ..                            ...            ...   ...            ...
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
middle_tn_schools.head()
# Out:
#                           name  school_rating  size  reduced_lunch  \
# 0  Allendale Elementary School              5   851             10
# 1          Anderson Elementary              2   412             71
# 2             Avoca Elementary              4   482             43
# 3                Bailey Middle              0   394             91
# 4          Barfield Elementary              4   948             26
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
middle_tn_schools.tail()
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# 342                 59.1                 65.2             16.9      Public
# 343                 93.9                 97.0             14.3      Public
# 344                 84.8                 76.7             14.1      Public
# 345                 93.3                 97.1             19.2      Public
# 346                  4.5                  1.2             16.5      Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
middle_tn_schools.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
middle_tn_schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 347 non-null    object
#  1   school_rating        347 non-null    int64
#  2   size                 347 non-null    int64
#  3   reduced_lunch        347 non-null    int64
#  4   state_percentile_16  347 non-null    float64
#  5   state_percentile_15  341 non-null    float64
#  6   stu_teach_ratio      347 non-null    float64
#  7   school_type          347 non-null    object
#  8   avg_score_15         341 non-null    float64
#  9   avg_score_16         347 non-null    float64
#  10  full_time_teachers   347 non-null    int64
#  11  percent_black        347 non-null    float64
#  12  percent_white        347 non-null    float64
#  13  percent_asian        347 non-null    float64
#  14  percent_hispanic     347 non-null    float64
# ...

# %%
middle_tn_schools.shape
# Out:
# (347, 15)

# %%
middle_tn_schools.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
df=middle_tn_schools.copy()

# %%
df
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 0     Allendale Elementary School              5   851             10
# 1             Anderson Elementary              2   412             71
# 2                Avoca Elementary              4   482             43
# 3                   Bailey Middle              0   394             91
# 4             Barfield Elementary              4   948             26
# ..                            ...            ...   ...            ...
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
#Fill missing values

# %%
#Slice the relevant column

# %%
# 1. state_percentile_15
df['state_percentile_15'].isnull().sum()
# Out:
# 6

# %%
df['state_percentile_15'].mean()
# Out:
# 58.24926686217009

# %%
df['state_percentile_15']=df['state_percentile_15'].fillna(58.2)

# %%
df['state_percentile_15'].isnull().sum()
# Out:
# 0

# %%
#2. avg_score_15
df['avg_score_15'].isnull().sum()
# Out:
# 6

# %%
df['avg_score_15'].mean()
# Out:
# 57.00469208211143

# %%
df['avg_score_15']=df['avg_score_15'].fillna(57)

# %%
df['avg_score_15'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    0
# stu_teach_ratio        0
# school_type            0
# avg_score_15           0
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
df.nunique()
# Out:
# name                   341
# school_rating            6
# size                   297
# reduced_lunch           91
# state_percentile_16    311
# state_percentile_15    299
# stu_teach_ratio        101
# school_type              4
# avg_score_15           282
# avg_score_16           288
# full_time_teachers      86
# percent_black          230
# percent_white          269
# percent_asian           84
# percent_hispanic       180
# dtype: int64

# %%
df.dtypes
# Out:
# name                    object
# school_rating            int64
# size                     int64
# reduced_lunch            int64
# state_percentile_16    float64
# state_percentile_15    float64
# stu_teach_ratio        float64
# school_type             object
# avg_score_15           float64
# avg_score_16           float64
# full_time_teachers       int64
# percent_black          float64
# percent_white          float64
# percent_asian          float64
# percent_hispanic       float64
# dtype: object

# %%
#convert dataframe to excel sheet

# %%
df.to_excel('data.xlsx', index=False)

# %%
df.to_excel('middle_tn_schools_filled.xlsx',index=False)

# %%
df.to_excel(r'C:\Users\pc\Downloads\middle_tn_schools_filled.xlsx',index=False)

# %% [markdown]
#      Phase 2 - Group data by school ratings

# %% [markdown]
# Chooses indicators that describe the student body (for example, reduced_lunch) or school
# administration (stu_teach_ratio) hoping they will explain school_rating. reduced_lunch is a
# variable measuring the average percentage of students per school enrolled in a federal
# program that provides lunches for students from lowerincome households. In short,
# reduced_lunch is a good proxy for household income.  Isolates ‘reduced_lunch’ and groups
# the data by ‘school_rating’ using pandas groupby method and then uses describe on the re
# shaped data

# %%
#reduced_lunch =household income

# %%
#Use groupby to bring distinct values together
#school_rating,reduced_lunch,stu_teach_ratio,
#reduced_lunch=average percentage of students per school

# %%
df1=pd.read_excel(r'C:\Users\pc\Downloads\middle_tn_schools_filled.xlsx')

# %%
df1
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 0     Allendale Elementary School              5   851             10
# 1             Anderson Elementary              2   412             71
# 2                Avoca Elementary              4   482             43
# 3                   Bailey Middle              0   394             91
# 4             Barfield Elementary              4   948             26
# ..                            ...            ...   ...            ...
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
df1.groupby('reduced_lunch')['stu_teach_ratio'].mean()
# Out:
# reduced_lunch
# 2     16.950000
# 3     17.733333
# 4     17.400000
# 5     16.700000
# 6     16.200000
#         ...
# 92    14.800000
# 93    14.150000
# 94    14.200000
# 97    15.100000
# 98    14.550000
# Name: stu_teach_ratio, Length: 91, dtype: float64

# %%
df1.groupby('reduced_lunch')[['stu_teach_ratio','school_rating','size']].mean()
# Out:
#                stu_teach_ratio  school_rating         size
# reduced_lunch
# 2                    16.950000           5.00   810.833333
# 3                    17.733333           5.00   800.666667
# 4                    17.400000           4.75  1199.000000
# 5                    16.700000           5.00   848.000000
# 6                    16.200000           5.00   549.500000
# ...                        ...            ...          ...
# 92                   14.800000           0.00   400.000000
# 93                   14.150000           0.50   444.500000
# 94                   14.200000           0.00   842.000000
# 97                   15.100000           1.00   575.000000
# 98                   14.550000           0.50   542.500000
#
# [91 rows x 3 columns]

# %%
df1.groupby('reduced_lunch')['school_rating'].mean()
# Out:
# reduced_lunch
# 2     5.00
# 3     5.00
# 4     4.75
# 5     5.00
# 6     5.00
#       ...
# 92    0.00
# 93    0.50
# 94    0.00
# 97    1.00
# 98    0.50
# Name: school_rating, Length: 91, dtype: float64

# %%
corr = df['reduced_lunch'].corr(df['school_rating'])
corr
# Out:
# -0.8157567373058027

# %%
print(corr)
# Out:
# -0.8157567373058027
